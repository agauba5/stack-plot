# %% [markdown]
# # Stack-plot example using random numbers

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# create some random data to plot

# %%
x = range(1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)


# print values to view generated results

print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.13165426 0.16566743 0.49796268 0.47159924 0.39480749 0.84252118
#  0.75020899 0.43407007 0.63106012 0.93932537 0.4206833  0.52239557
#  0.88306337 0.79015538 0.12124774 0.94880373 0.17920264 0.31214045
#  0.8856179  0.73599021]
# [0.65374322 0.19005081 0.43533719 0.50938999 0.99609775 0.78985105
#  0.43791847 0.61075139 0.58433135 0.02308529 0.71394441 0.69279206
#  0.12881601 0.80073468 0.24802846 0.85565301 0.17658409 0.02009063
#  0.77874664 0.45243605]

# %%
# setup legend for plot 

plt.plot([], [], color='r', label='y1')
plt.plot([], [], color='b', label='y2')

# setup the plot
plt.stackplot(x,y1,y2, colors= ['r', 'b'])
plt.title('stack-plot random numbers')
plt.legend()
plt.show()
